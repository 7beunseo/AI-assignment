# %% [markdown]
# <a href="https://colab.research.google.com/github/7beunseo/AI-assignment/blob/main/fin/Cifar10/Cifar10_mlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

class_names = [
    "Airplane", "Automobile", "Bird", "Cat", "Deer",
    "Dog", "Frog", "Horse", "Ship", "Truck"
]

(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()


print("X_train.shape:", X_train.shape)
print("y_train.shape:", y_train.shape)
print("X_test.shape:", X_test.shape)
print("y_test.shape:", y_test.shape)

# plt.figure(figsize=(10, 2))
# for i in range(5):
#     plt.subplot(1, 5, i + 1)
#     plt.imshow(X_train[i])
#     plt.title(class_names[y_train[i][0]])  # CIFAR-10 클래스 이름 표시
#     plt.axis('off')
# plt.show()

# 레이블을 one-hot encoding으로 변환
train_labels = keras.utils.to_categorical(y_train, 10)
test_labels = keras.utils.to_categorical(y_test, 10)

print('train_labels.shape (one-hot) =', train_labels.shape)
print('test_labels.shape (one-hot) =', test_labels.shape)

train_images, test_images = X_train / 255, X_test / 255


model = keras.models.Sequential([
    keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
    keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Dropout(0.25),

    keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Dropout(0.25),

    keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    # keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Dropout(0.25),

    # keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
    # keras.layers.MaxPooling2D((2, 2)),
    # keras.layers.Dropout(0.25),

    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation='softmax')
])

model.summary()


model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

hist = model.fit(train_images, train_labels, batch_size=256,
                 epochs=200, validation_split=0.25)

plt.plot(hist.history['accuracy'], 'b-', label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], 'r--', label='Validation Accuracy')
plt.plot(hist.history['loss'], 'g-', label='Training Loss')
plt.plot(hist.history['val_loss'], 'y--', label='Validation Loss')
plt.legend()
plt.show()


test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('테스트 정확도:', test_acc)


images = test_images[:25]
pred = np.argmax(model.predict(images), axis=1)
print('예측값 =', pred)
print('실제값 =', np.argmax(test_labels[:25], axis=1))

def plot_images(images, labels, images_per_row=5):
 n_images = len(images)
 n_rows = (n_images-1) // images_per_row + 1
 fig, ax = plt.subplots(n_rows, images_per_row,
                        figsize = (images_per_row * 2, n_rows * 2))
 for i in range(n_rows):
     for j in range(images_per_row):
         if i*images_per_row + j >= n_images: break
         img_idx = i*images_per_row + j
         a_image = images[img_idx].reshape(32,32,3)
         if n_rows>1: axis = ax[i, j]
         else: axis = ax[j]
         axis.get_xaxis().set_visible(False)
         axis.get_yaxis().set_visible(False)
         label = class_names[labels[img_idx]]
         axis.set_title(label)
         axis.imshow(a_image, cmap='gray', interpolation='nearest')

plot_images(images, pred, images_per_row = 5)

pred = np.argmax(model.predict(test_images), axis=1)
actual = np.argmax(test_labels, axis=1)  # test_labels를 원래 형태로 변환

print('예측값 =', pred)
print('실제값 =', actual)

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 혼동 행렬 생성
conf_mat = confusion_matrix(actual, pred)

# 혼동 행렬 시각화
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# X_train.shape: (50000, 32, 32, 3)
# y_train.shape: (50000, 1)
# X_test.shape: (10000, 32, 32, 3)
# y_test.shape: (10000, 1)
# train_labels.shape (one-hot) = (50000, 10)
# test_labels.shape (one-hot) = (10000, 10)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 402,986 (1.54 MB)
#  Trainable params: 402,986 (1.54 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 26s 71ms/step - accuracy: 0.1949 - loss: 2.1294 - val_accuracy: 0.4338 - val_loss: 1.5554
# Epoch 2/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4202 - loss: 1.5913 - val_accuracy: 0.5177 - val_loss: 1.3548
# Epoch 3/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.4971 - loss: 1.3892 - val_accuracy: 0.5848 - val_loss: 1.1474
# Epoch 4/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.5510 - loss: 1.2449 - val_accuracy: 0.6218 - val_loss: 1.0531
# Epoch 5/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.5843 - loss: 1.1680 - val_accuracy: 0.6552 - val_loss: 0.9772
# Epoch 6/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6152 - loss: 1.0890 - val_accuracy: 0.6766 - val_loss: 0.9287
# Epoch 7/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6423 - loss: 1.0170 - val_accuracy: 0.6756 - val_loss: 0.9271
# Epoch 8/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6625 - loss: 0.9675 - val_accuracy: 0.7034 - val_loss: 0.8503
# Epoch 9/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6701 - loss: 0.9282 - val_accuracy: 0.7185 - val_loss: 0.8040
# Epoch 10/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.6876 - loss: 0.8793 - val_accuracy: 0.7350 - val_loss: 0.7600
# Epoch 11/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7003 - loss: 0.8562 - val_accuracy: 0.7389 - val_loss: 0.7509
# Epoch 12/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7167 - loss: 0.8115 - val_accuracy: 0.7501 - val_loss: 0.7126
# Epoch 13/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.7268 - loss: 0.7787 - val_accuracy: 0.7462 - val_loss: 0.7242
# Epoch 14/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7353 - loss: 0.7563 - val_accuracy: 0.7619 - val_loss: 0.6836
# Epoch 15/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7411 - loss: 0.7341 - val_accuracy: 0.7610 - val_loss: 0.6798
# Epoch 16/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7543 - loss: 0.6983 - val_accuracy: 0.7730 - val_loss: 0.6583
# Epoch 17/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7608 - loss: 0.6894 - val_accuracy: 0.7614 - val_loss: 0.6897
# Epoch 18/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7613 - loss: 0.6786 - val_accuracy: 0.7748 - val_loss: 0.6503
# Epoch 19/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7719 - loss: 0.6588 - val_accuracy: 0.7883 - val_loss: 0.6150
# Epoch 20/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7778 - loss: 0.6396 - val_accuracy: 0.7902 - val_loss: 0.6144
# Epoch 21/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.7817 - loss: 0.6135 - val_accuracy: 0.7873 - val_loss: 0.6127
# Epoch 22/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7853 - loss: 0.6072 - val_accuracy: 0.7978 - val_loss: 0.5898
# Epoch 23/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7883 - loss: 0.5947 - val_accuracy: 0.7914 - val_loss: 0.5973
# Epoch 24/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7939 - loss: 0.5822 - val_accuracy: 0.8023 - val_loss: 0.5782
# Epoch 25/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7971 - loss: 0.5742 - val_accuracy: 0.7993 - val_loss: 0.5856
# Epoch 26/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8032 - loss: 0.5682 - val_accuracy: 0.7858 - val_loss: 0.6202
# Epoch 27/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8006 - loss: 0.5635 - val_accuracy: 0.8041 - val_loss: 0.5724
# Epoch 28/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8052 - loss: 0.5524 - val_accuracy: 0.8018 - val_loss: 0.5734
# Epoch 29/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8139 - loss: 0.5308 - val_accuracy: 0.8024 - val_loss: 0.5813
# Epoch 30/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8118 - loss: 0.5277 - val_accuracy: 0.8089 - val_loss: 0.5567
# Epoch 31/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8219 - loss: 0.5087 - val_accuracy: 0.7948 - val_loss: 0.6058
# Epoch 32/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8146 - loss: 0.5262 - val_accuracy: 0.7996 - val_loss: 0.5869
# Epoch 33/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8202 - loss: 0.5115 - val_accuracy: 0.8101 - val_loss: 0.5507
# Epoch 34/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8252 - loss: 0.4919 - val_accuracy: 0.8058 - val_loss: 0.5801
# Epoch 35/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8244 - loss: 0.4961 - val_accuracy: 0.8094 - val_loss: 0.5570
# Epoch 36/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8294 - loss: 0.4889 - val_accuracy: 0.8088 - val_loss: 0.5581
# Epoch 37/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8321 - loss: 0.4747 - val_accuracy: 0.8071 - val_loss: 0.5695
# Epoch 38/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8308 - loss: 0.4818 - val_accuracy: 0.8104 - val_loss: 0.5573
# Epoch 39/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8380 - loss: 0.4636 - val_accuracy: 0.8098 - val_loss: 0.5599
# Epoch 40/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8357 - loss: 0.4642 - val_accuracy: 0.8117 - val_loss: 0.5538
# Epoch 41/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8382 - loss: 0.4503 - val_accuracy: 0.8048 - val_loss: 0.5884
# Epoch 42/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8350 - loss: 0.4653 - val_accuracy: 0.8171 - val_loss: 0.5497
# Epoch 43/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8436 - loss: 0.4443 - val_accuracy: 0.8182 - val_loss: 0.5433
# Epoch 44/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8446 - loss: 0.4382 - val_accuracy: 0.8175 - val_loss: 0.5539
# Epoch 45/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8423 - loss: 0.4377 - val_accuracy: 0.8140 - val_loss: 0.5788
# Epoch 46/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8432 - loss: 0.4499 - val_accuracy: 0.8156 - val_loss: 0.5459
# Epoch 47/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8459 - loss: 0.4316 - val_accuracy: 0.8170 - val_loss: 0.5502
# Epoch 48/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8506 - loss: 0.4231 - val_accuracy: 0.8163 - val_loss: 0.5508
# Epoch 49/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8504 - loss: 0.4263 - val_accuracy: 0.8147 - val_loss: 0.5701
# Epoch 50/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8533 - loss: 0.4140 - val_accuracy: 0.8182 - val_loss: 0.5409
# Epoch 51/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8516 - loss: 0.4220 - val_accuracy: 0.8141 - val_loss: 0.5748
# Epoch 52/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8574 - loss: 0.4001 - val_accuracy: 0.8202 - val_loss: 0.5437
# Epoch 53/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8524 - loss: 0.4112 - val_accuracy: 0.8080 - val_loss: 0.5778
# Epoch 54/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8558 - loss: 0.4029 - val_accuracy: 0.8230 - val_loss: 0.5435
# Epoch 55/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8633 - loss: 0.3903 - val_accuracy: 0.8216 - val_loss: 0.5467
# Epoch 56/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8609 - loss: 0.3932 - val_accuracy: 0.8218 - val_loss: 0.5512
# Epoch 57/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8599 - loss: 0.3976 - val_accuracy: 0.8194 - val_loss: 0.5623
# Epoch 58/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8620 - loss: 0.3956 - val_accuracy: 0.8228 - val_loss: 0.5529
# Epoch 59/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8633 - loss: 0.3814 - val_accuracy: 0.8246 - val_loss: 0.5457
# Epoch 60/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8619 - loss: 0.3858 - val_accuracy: 0.8205 - val_loss: 0.5545
# Epoch 61/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8618 - loss: 0.3950 - val_accuracy: 0.8200 - val_loss: 0.5571
# Epoch 62/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.8667 - loss: 0.3723 - val_accuracy: 0.8202 - val_loss: 0.5591
# Epoch 63/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8655 - loss: 0.3736 - val_accuracy: 0.8239 - val_loss: 0.5519
# Epoch 64/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8629 - loss: 0.3834 - val_accuracy: 0.8194 - val_loss: 0.5740
# Epoch 65/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8644 - loss: 0.3779 - val_accuracy: 0.8218 - val_loss: 0.5646
# Epoch 66/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8690 - loss: 0.3763 - val_accuracy: 0.8229 - val_loss: 0.5553
# Epoch 67/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8700 - loss: 0.3639 - val_accuracy: 0.8218 - val_loss: 0.5553
# Epoch 68/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8702 - loss: 0.3661 - val_accuracy: 0.8266 - val_loss: 0.5398
# Epoch 69/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8719 - loss: 0.3587 - val_accuracy: 0.8183 - val_loss: 0.5801
# Epoch 70/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8708 - loss: 0.3628 - val_accuracy: 0.8189 - val_loss: 0.5827
# Epoch 71/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8721 - loss: 0.3571 - val_accuracy: 0.8232 - val_loss: 0.5728
# Epoch 72/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8740 - loss: 0.3563 - val_accuracy: 0.8246 - val_loss: 0.5571
# Epoch 73/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8738 - loss: 0.3538 - val_accuracy: 0.8266 - val_loss: 0.5549
# Epoch 74/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8723 - loss: 0.3674 - val_accuracy: 0.8286 - val_loss: 0.5480
# Epoch 75/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8750 - loss: 0.3531 - val_accuracy: 0.8198 - val_loss: 0.5626
# Epoch 76/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8758 - loss: 0.3460 - val_accuracy: 0.8230 - val_loss: 0.5502
# Epoch 77/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8781 - loss: 0.3406 - val_accuracy: 0.8214 - val_loss: 0.5669
# Epoch 78/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8771 - loss: 0.3458 - val_accuracy: 0.8307 - val_loss: 0.5404
# Epoch 79/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8782 - loss: 0.3462 - val_accuracy: 0.8242 - val_loss: 0.5615
# Epoch 80/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8783 - loss: 0.3378 - val_accuracy: 0.8252 - val_loss: 0.5561
# Epoch 81/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8758 - loss: 0.3464 - val_accuracy: 0.8260 - val_loss: 0.5393
# Epoch 82/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8814 - loss: 0.3353 - val_accuracy: 0.8283 - val_loss: 0.5641
# Epoch 83/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8792 - loss: 0.3413 - val_accuracy: 0.8238 - val_loss: 0.5585
# Epoch 84/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8780 - loss: 0.3357 - val_accuracy: 0.8214 - val_loss: 0.5547
# Epoch 85/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8787 - loss: 0.3517 - val_accuracy: 0.8225 - val_loss: 0.5862
# Epoch 86/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8824 - loss: 0.3348 - val_accuracy: 0.8235 - val_loss: 0.5630
# Epoch 87/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8800 - loss: 0.3364 - val_accuracy: 0.8247 - val_loss: 0.5662
# Epoch 88/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8854 - loss: 0.3268 - val_accuracy: 0.8262 - val_loss: 0.5603
# Epoch 89/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8823 - loss: 0.3280 - val_accuracy: 0.8274 - val_loss: 0.5595
# Epoch 90/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8854 - loss: 0.3190 - val_accuracy: 0.8274 - val_loss: 0.5561
# Epoch 91/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8834 - loss: 0.3323 - val_accuracy: 0.8244 - val_loss: 0.5693
# Epoch 92/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8933 - loss: 0.3089 - val_accuracy: 0.8312 - val_loss: 0.5521
# Epoch 93/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8854 - loss: 0.3228 - val_accuracy: 0.8249 - val_loss: 0.5920
# Epoch 94/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8839 - loss: 0.3246 - val_accuracy: 0.8256 - val_loss: 0.5566
# Epoch 95/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8865 - loss: 0.3155 - val_accuracy: 0.8294 - val_loss: 0.5577
# Epoch 96/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8884 - loss: 0.3125 - val_accuracy: 0.8288 - val_loss: 0.5638
# Epoch 97/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8887 - loss: 0.3151 - val_accuracy: 0.8312 - val_loss: 0.5529
# Epoch 98/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8896 - loss: 0.3055 - val_accuracy: 0.8285 - val_loss: 0.5590
# Epoch 99/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8887 - loss: 0.3142 - val_accuracy: 0.8278 - val_loss: 0.5510
# Epoch 100/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8912 - loss: 0.3079 - val_accuracy: 0.8303 - val_loss: 0.5616
# Epoch 101/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8895 - loss: 0.3056 - val_accuracy: 0.8290 - val_loss: 0.5769
# Epoch 102/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8883 - loss: 0.3159 - val_accuracy: 0.8312 - val_loss: 0.5582
# Epoch 103/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8946 - loss: 0.3008 - val_accuracy: 0.8345 - val_loss: 0.5424
# Epoch 104/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.8963 - loss: 0.2918 - val_accuracy: 0.8306 - val_loss: 0.5574
# Epoch 105/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8952 - loss: 0.2997 - val_accuracy: 0.8290 - val_loss: 0.5647
# Epoch 106/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8916 - loss: 0.3090 - val_accuracy: 0.8299 - val_loss: 0.5552
# Epoch 107/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8914 - loss: 0.3087 - val_accuracy: 0.8298 - val_loss: 0.5450
# Epoch 108/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8889 - loss: 0.3108 - val_accuracy: 0.8248 - val_loss: 0.5823
# Epoch 109/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8901 - loss: 0.3146 - val_accuracy: 0.8297 - val_loss: 0.5553
# Epoch 110/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8952 - loss: 0.2921 - val_accuracy: 0.8304 - val_loss: 0.5530
# Epoch 111/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8975 - loss: 0.2894 - val_accuracy: 0.8302 - val_loss: 0.5659
# Epoch 112/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8988 - loss: 0.2870 - val_accuracy: 0.8327 - val_loss: 0.5525
# Epoch 113/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8953 - loss: 0.2985 - val_accuracy: 0.8308 - val_loss: 0.5635
# Epoch 114/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8996 - loss: 0.2869 - val_accuracy: 0.8303 - val_loss: 0.5685
# Epoch 115/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8977 - loss: 0.2851 - val_accuracy: 0.8328 - val_loss: 0.5719
# Epoch 116/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8963 - loss: 0.2915 - val_accuracy: 0.8331 - val_loss: 0.5632
# Epoch 117/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8980 - loss: 0.2870 - val_accuracy: 0.8282 - val_loss: 0.5709
# Epoch 118/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8945 - loss: 0.3000 - val_accuracy: 0.8361 - val_loss: 0.5539
# Epoch 119/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8988 - loss: 0.2877 - val_accuracy: 0.8311 - val_loss: 0.5773
# Epoch 120/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8985 - loss: 0.2904 - val_accuracy: 0.8304 - val_loss: 0.5820
# Epoch 121/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9006 - loss: 0.2824 - val_accuracy: 0.8335 - val_loss: 0.5601
# Epoch 122/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8997 - loss: 0.2920 - val_accuracy: 0.8316 - val_loss: 0.5659
# Epoch 123/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8979 - loss: 0.2949 - val_accuracy: 0.8323 - val_loss: 0.5656
# Epoch 124/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8988 - loss: 0.2873 - val_accuracy: 0.8249 - val_loss: 0.6027
# Epoch 125/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8985 - loss: 0.2857 - val_accuracy: 0.8305 - val_loss: 0.5755
# Epoch 126/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9008 - loss: 0.2770 - val_accuracy: 0.8275 - val_loss: 0.5742
# Epoch 127/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8985 - loss: 0.2870 - val_accuracy: 0.8299 - val_loss: 0.5777
# Epoch 128/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8985 - loss: 0.2832 - val_accuracy: 0.8333 - val_loss: 0.5545
# Epoch 129/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8996 - loss: 0.2806 - val_accuracy: 0.8314 - val_loss: 0.5545
# Epoch 130/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9021 - loss: 0.2803 - val_accuracy: 0.8321 - val_loss: 0.5701
# Epoch 131/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9011 - loss: 0.2726 - val_accuracy: 0.8313 - val_loss: 0.5686
# Epoch 132/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8984 - loss: 0.2858 - val_accuracy: 0.8334 - val_loss: 0.5740
# Epoch 133/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9014 - loss: 0.2793 - val_accuracy: 0.8335 - val_loss: 0.5588
# Epoch 134/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9033 - loss: 0.2699 - val_accuracy: 0.8324 - val_loss: 0.5623
# Epoch 135/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9016 - loss: 0.2762 - val_accuracy: 0.8326 - val_loss: 0.5526
# Epoch 136/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9038 - loss: 0.2772 - val_accuracy: 0.8352 - val_loss: 0.5475
# Epoch 137/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9015 - loss: 0.2817 - val_accuracy: 0.8346 - val_loss: 0.5611
# Epoch 138/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9030 - loss: 0.2743 - val_accuracy: 0.8327 - val_loss: 0.5612
# Epoch 139/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9051 - loss: 0.2695 - val_accuracy: 0.8319 - val_loss: 0.5739
# Epoch 140/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9066 - loss: 0.2666 - val_accuracy: 0.8272 - val_loss: 0.5938
# Epoch 141/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9014 - loss: 0.2857 - val_accuracy: 0.8340 - val_loss: 0.5637
# Epoch 142/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9040 - loss: 0.2711 - val_accuracy: 0.8314 - val_loss: 0.5805
# Epoch 143/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9053 - loss: 0.2717 - val_accuracy: 0.8270 - val_loss: 0.6030
# Epoch 144/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9070 - loss: 0.2677 - val_accuracy: 0.8317 - val_loss: 0.5915
# Epoch 145/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9027 - loss: 0.2729 - val_accuracy: 0.8317 - val_loss: 0.5826
# Epoch 146/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9096 - loss: 0.2528 - val_accuracy: 0.8342 - val_loss: 0.5651
# Epoch 147/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9073 - loss: 0.2652 - val_accuracy: 0.8286 - val_loss: 0.5850
# Epoch 148/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9026 - loss: 0.2760 - val_accuracy: 0.8315 - val_loss: 0.5761
# Epoch 149/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9075 - loss: 0.2625 - val_accuracy: 0.8281 - val_loss: 0.5929
# Epoch 150/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9031 - loss: 0.2743 - val_accuracy: 0.8290 - val_loss: 0.5829
# Epoch 151/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9033 - loss: 0.2686 - val_accuracy: 0.8366 - val_loss: 0.5598
# Epoch 152/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9062 - loss: 0.2628 - val_accuracy: 0.8372 - val_loss: 0.5556
# Epoch 153/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9031 - loss: 0.2690 - val_accuracy: 0.8366 - val_loss: 0.5532
# Epoch 154/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9064 - loss: 0.2693 - val_accuracy: 0.8344 - val_loss: 0.5811
# Epoch 155/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9047 - loss: 0.2659 - val_accuracy: 0.8366 - val_loss: 0.5607
# Epoch 156/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9077 - loss: 0.2610 - val_accuracy: 0.8326 - val_loss: 0.5862
# Epoch 157/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9118 - loss: 0.2557 - val_accuracy: 0.8350 - val_loss: 0.5682
# Epoch 158/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9064 - loss: 0.2627 - val_accuracy: 0.8326 - val_loss: 0.5886
# Epoch 159/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9110 - loss: 0.2525 - val_accuracy: 0.8345 - val_loss: 0.5695
# Epoch 160/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9073 - loss: 0.2638 - val_accuracy: 0.8316 - val_loss: 0.5577
# Epoch 161/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9091 - loss: 0.2601 - val_accuracy: 0.8355 - val_loss: 0.5638
# Epoch 162/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9110 - loss: 0.2523 - val_accuracy: 0.8367 - val_loss: 0.5524
# Epoch 163/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9096 - loss: 0.2561 - val_accuracy: 0.8318 - val_loss: 0.5649
# Epoch 164/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9088 - loss: 0.2568 - val_accuracy: 0.8297 - val_loss: 0.5922
# Epoch 165/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9074 - loss: 0.2643 - val_accuracy: 0.8323 - val_loss: 0.5871
# Epoch 166/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9112 - loss: 0.2519 - val_accuracy: 0.8334 - val_loss: 0.5742
# Epoch 167/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9107 - loss: 0.2537 - val_accuracy: 0.8371 - val_loss: 0.5846
# Epoch 168/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9094 - loss: 0.2556 - val_accuracy: 0.8336 - val_loss: 0.5660
# Epoch 169/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9080 - loss: 0.2560 - val_accuracy: 0.8327 - val_loss: 0.5684
# Epoch 170/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9110 - loss: 0.2448 - val_accuracy: 0.8359 - val_loss: 0.5733
# Epoch 171/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9105 - loss: 0.2549 - val_accuracy: 0.8284 - val_loss: 0.5896
# Epoch 172/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9116 - loss: 0.2600 - val_accuracy: 0.8360 - val_loss: 0.5653
# Epoch 173/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9124 - loss: 0.2519 - val_accuracy: 0.8387 - val_loss: 0.5723
# Epoch 174/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9118 - loss: 0.2494 - val_accuracy: 0.8368 - val_loss: 0.5652
# Epoch 175/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9110 - loss: 0.2565 - val_accuracy: 0.8377 - val_loss: 0.5665
# Epoch 176/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9118 - loss: 0.2492 - val_accuracy: 0.8330 - val_loss: 0.5885
# Epoch 177/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9141 - loss: 0.2408 - val_accuracy: 0.8370 - val_loss: 0.5649
# Epoch 178/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9108 - loss: 0.2471 - val_accuracy: 0.8349 - val_loss: 0.5719
# Epoch 179/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9158 - loss: 0.2466 - val_accuracy: 0.8366 - val_loss: 0.5646
# Epoch 180/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9129 - loss: 0.2487 - val_accuracy: 0.8379 - val_loss: 0.5710
# Epoch 181/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9080 - loss: 0.2579 - val_accuracy: 0.8350 - val_loss: 0.5964
# Epoch 182/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9118 - loss: 0.2522 - val_accuracy: 0.8350 - val_loss: 0.5746
# Epoch 183/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9103 - loss: 0.2548 - val_accuracy: 0.8362 - val_loss: 0.5790
# Epoch 184/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9122 - loss: 0.2451 - val_accuracy: 0.8321 - val_loss: 0.5872
# Epoch 185/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9117 - loss: 0.2450 - val_accuracy: 0.8331 - val_loss: 0.5754
# Epoch 186/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9125 - loss: 0.2459 - val_accuracy: 0.8362 - val_loss: 0.5719
# Epoch 187/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9122 - loss: 0.2444 - val_accuracy: 0.8387 - val_loss: 0.5775
# Epoch 188/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9126 - loss: 0.2493 - val_accuracy: 0.8338 - val_loss: 0.5672
# Epoch 189/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9158 - loss: 0.2412 - val_accuracy: 0.8344 - val_loss: 0.5820
# Epoch 190/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9142 - loss: 0.2433 - val_accuracy: 0.8368 - val_loss: 0.5803
# Epoch 191/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9165 - loss: 0.2407 - val_accuracy: 0.8348 - val_loss: 0.5685
# Epoch 192/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9167 - loss: 0.2380 - val_accuracy: 0.8366 - val_loss: 0.5726
# Epoch 193/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9156 - loss: 0.2431 - val_accuracy: 0.8358 - val_loss: 0.5791
# Epoch 194/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9158 - loss: 0.2350 - val_accuracy: 0.8355 - val_loss: 0.6078
# Epoch 195/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9123 - loss: 0.2424 - val_accuracy: 0.8323 - val_loss: 0.6000
# Epoch 196/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9147 - loss: 0.2438 - val_accuracy: 0.8372 - val_loss: 0.5634
# Epoch 197/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9173 - loss: 0.2365 - val_accuracy: 0.8340 - val_loss: 0.5918
# Epoch 198/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9156 - loss: 0.2371 - val_accuracy: 0.8350 - val_loss: 0.5944
# Epoch 199/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9168 - loss: 0.2344 - val_accuracy: 0.8356 - val_loss: 0.5784
# Epoch 200/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9164 - loss: 0.2369 - val_accuracy: 0.8351 - val_loss: 0.5785
# 313/313 - 2s - 6ms/step - accuracy: 0.8385 - loss: 0.5836
# 테스트 정확도: 0.8385000228881836
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# 예측값 = [3 8 8 8 6 6 1 6 3 1 0 9 5 7 9 8 5 7 8 6 7 0 4 9 4]
# 실제값 = [3 8 8 0 6 6 1 6 3 1 0 9 5 7 9 8 5 7 8 6 7 0 4 9 5]
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 예측값 = [3 8 8 ... 5 1 7]
# 실제값 = [3 8 8 ... 5 1 7]
