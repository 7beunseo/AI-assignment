# %% [markdown]
# <a href="https://colab.research.google.com/github/7beunseo/AI-assignment/blob/main/fin/Cifar10/Cifar10_mlp_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

class_names = [
    "Airplane", "Automobile", "Bird", "Cat", "Deer",
    "Dog", "Frog", "Horse", "Ship", "Truck"
]

(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()


print("X_train.shape:", X_train.shape)
print("y_train.shape:", y_train.shape)
print("X_test.shape:", X_test.shape)
print("y_test.shape:", y_test.shape)

# plt.figure(figsize=(10, 2))
# for i in range(5):
#     plt.subplot(1, 5, i + 1)
#     plt.imshow(X_train[i])
#     plt.title(class_names[y_train[i][0]])  # CIFAR-10 클래스 이름 표시
#     plt.axis('off')
# plt.show()

# 레이블을 one-hot encoding으로 변환
train_labels = keras.utils.to_categorical(y_train, 10)
test_labels = keras.utils.to_categorical(y_test, 10)

print('train_labels.shape (one-hot) =', train_labels.shape)
print('test_labels.shape (one-hot) =', test_labels.shape)

train_images, test_images = X_train / 255, X_test / 255


model = keras.models.Sequential([
    keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
    keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Dropout(0.25),

    keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Dropout(0.25),

    keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    # keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Dropout(0.25),

    # keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
    # keras.layers.MaxPooling2D((2, 2)),
    # keras.layers.Dropout(0.25),

    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation='softmax')
])

model.summary()

from tensorflow.keras.optimizers import Adam

# 학습률을 0.0005로 설정
model.compile(optimizer=Adam(learning_rate=0.0005),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 모델 학습
hist = model.fit(train_images, train_labels, batch_size=256,
                 epochs=200, validation_split=0.25)

plt.plot(hist.history['accuracy'], 'b-', label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], 'r--', label='Validation Accuracy')
plt.plot(hist.history['loss'], 'g-', label='Training Loss')
plt.plot(hist.history['val_loss'], 'y--', label='Validation Loss')
plt.legend()
plt.show()


test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('테스트 정확도:', test_acc)


images = test_images[:25]
pred = np.argmax(model.predict(images), axis=1)
print('예측값 =', pred)
print('실제값 =', np.argmax(test_labels[:25], axis=1))

def plot_images(images, labels, images_per_row=5):
 n_images = len(images)
 n_rows = (n_images-1) // images_per_row + 1
 fig, ax = plt.subplots(n_rows, images_per_row,
                        figsize = (images_per_row * 2, n_rows * 2))
 for i in range(n_rows):
     for j in range(images_per_row):
         if i*images_per_row + j >= n_images: break
         img_idx = i*images_per_row + j
         a_image = images[img_idx].reshape(32,32,3)
         if n_rows>1: axis = ax[i, j]
         else: axis = ax[j]
         axis.get_xaxis().set_visible(False)
         axis.get_yaxis().set_visible(False)
         label = class_names[labels[img_idx]]
         axis.set_title(label)
         axis.imshow(a_image, cmap='gray', interpolation='nearest')

plot_images(images, pred, images_per_row = 5)

pred = np.argmax(model.predict(test_images), axis=1)
actual = np.argmax(test_labels, axis=1)  # test_labels를 원래 형태로 변환

print('예측값 =', pred)
print('실제값 =', actual)

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 혼동 행렬 생성
conf_mat = confusion_matrix(actual, pred)

# 혼동 행렬 시각화
plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# X_train.shape: (50000, 32, 32, 3)
# y_train.shape: (50000, 1)
# X_test.shape: (10000, 32, 32, 3)
# y_test.shape: (10000, 1)
# train_labels.shape (one-hot) = (50000, 10)
# test_labels.shape (one-hot) = (10000, 10)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_15 (Conv2D)                   │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_16 (Conv2D)                   │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 402,986 (1.54 MB)
#  Trainable params: 402,986 (1.54 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - accuracy: 0.1816 - loss: 2.1710 - val_accuracy: 0.3986 - val_loss: 1.6749
# Epoch 2/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.3721 - loss: 1.7167 - val_accuracy: 0.4609 - val_loss: 1.4969
# Epoch 3/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.4411 - loss: 1.5405 - val_accuracy: 0.5103 - val_loss: 1.3538
# Epoch 4/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.4810 - loss: 1.4277 - val_accuracy: 0.5408 - val_loss: 1.2630
# Epoch 5/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.5238 - loss: 1.3272 - val_accuracy: 0.5892 - val_loss: 1.1721
# Epoch 6/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5577 - loss: 1.2338 - val_accuracy: 0.6230 - val_loss: 1.0742
# Epoch 7/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5909 - loss: 1.1606 - val_accuracy: 0.6464 - val_loss: 1.0171
# Epoch 8/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6082 - loss: 1.1000 - val_accuracy: 0.6487 - val_loss: 0.9941
# Epoch 9/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6254 - loss: 1.0648 - val_accuracy: 0.6822 - val_loss: 0.9115
# Epoch 10/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6400 - loss: 1.0208 - val_accuracy: 0.6951 - val_loss: 0.8728
# Epoch 11/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6578 - loss: 0.9763 - val_accuracy: 0.6928 - val_loss: 0.8700
# Epoch 12/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6701 - loss: 0.9458 - val_accuracy: 0.7092 - val_loss: 0.8349
# Epoch 13/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6782 - loss: 0.9233 - val_accuracy: 0.7017 - val_loss: 0.8457
# Epoch 14/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6874 - loss: 0.9027 - val_accuracy: 0.7247 - val_loss: 0.7841
# Epoch 15/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6956 - loss: 0.8669 - val_accuracy: 0.7326 - val_loss: 0.7676
# Epoch 16/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7030 - loss: 0.8516 - val_accuracy: 0.7432 - val_loss: 0.7368
# Epoch 17/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7102 - loss: 0.8190 - val_accuracy: 0.7470 - val_loss: 0.7360
# Epoch 18/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7189 - loss: 0.8019 - val_accuracy: 0.7487 - val_loss: 0.7152
# Epoch 19/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7290 - loss: 0.7861 - val_accuracy: 0.7591 - val_loss: 0.6950
# Epoch 20/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7327 - loss: 0.7708 - val_accuracy: 0.7596 - val_loss: 0.6994
# Epoch 21/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7408 - loss: 0.7438 - val_accuracy: 0.7626 - val_loss: 0.6819
# Epoch 22/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7412 - loss: 0.7368 - val_accuracy: 0.7702 - val_loss: 0.6680
# Epoch 23/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7459 - loss: 0.7253 - val_accuracy: 0.7689 - val_loss: 0.6671
# Epoch 24/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7521 - loss: 0.7043 - val_accuracy: 0.7758 - val_loss: 0.6434
# Epoch 25/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7571 - loss: 0.6918 - val_accuracy: 0.7746 - val_loss: 0.6518
# Epoch 26/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7558 - loss: 0.6882 - val_accuracy: 0.7810 - val_loss: 0.6278
# Epoch 27/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7627 - loss: 0.6770 - val_accuracy: 0.7838 - val_loss: 0.6224
# Epoch 28/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7700 - loss: 0.6617 - val_accuracy: 0.7809 - val_loss: 0.6242
# Epoch 29/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7701 - loss: 0.6507 - val_accuracy: 0.7779 - val_loss: 0.6375
# Epoch 30/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7774 - loss: 0.6462 - val_accuracy: 0.7879 - val_loss: 0.6156
# Epoch 31/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7821 - loss: 0.6198 - val_accuracy: 0.7851 - val_loss: 0.6207
# Epoch 32/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7871 - loss: 0.6038 - val_accuracy: 0.7870 - val_loss: 0.6111
# Epoch 33/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7888 - loss: 0.6027 - val_accuracy: 0.7979 - val_loss: 0.5885
# Epoch 34/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7905 - loss: 0.5891 - val_accuracy: 0.7882 - val_loss: 0.6069
# Epoch 35/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7959 - loss: 0.5852 - val_accuracy: 0.7930 - val_loss: 0.5971
# Epoch 36/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7946 - loss: 0.5857 - val_accuracy: 0.7988 - val_loss: 0.5803
# Epoch 37/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7993 - loss: 0.5725 - val_accuracy: 0.7982 - val_loss: 0.5912
# Epoch 38/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7985 - loss: 0.5612 - val_accuracy: 0.7952 - val_loss: 0.5899
# Epoch 39/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8024 - loss: 0.5540 - val_accuracy: 0.7981 - val_loss: 0.5868
# Epoch 40/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8052 - loss: 0.5492 - val_accuracy: 0.7954 - val_loss: 0.5976
# Epoch 41/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8091 - loss: 0.5387 - val_accuracy: 0.8055 - val_loss: 0.5729
# Epoch 42/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8149 - loss: 0.5253 - val_accuracy: 0.8016 - val_loss: 0.5721
# Epoch 43/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8146 - loss: 0.5276 - val_accuracy: 0.8044 - val_loss: 0.5640
# Epoch 44/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8223 - loss: 0.5149 - val_accuracy: 0.8070 - val_loss: 0.5629
# Epoch 45/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8138 - loss: 0.5211 - val_accuracy: 0.8106 - val_loss: 0.5572
# Epoch 46/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8210 - loss: 0.5018 - val_accuracy: 0.8064 - val_loss: 0.5648
# Epoch 47/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8247 - loss: 0.4971 - val_accuracy: 0.8102 - val_loss: 0.5563
# Epoch 48/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8278 - loss: 0.4872 - val_accuracy: 0.8107 - val_loss: 0.5564
# Epoch 49/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8241 - loss: 0.4973 - val_accuracy: 0.8053 - val_loss: 0.5715
# Epoch 50/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8289 - loss: 0.4804 - val_accuracy: 0.8087 - val_loss: 0.5635
# Epoch 51/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8293 - loss: 0.4823 - val_accuracy: 0.8117 - val_loss: 0.5664
# Epoch 52/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8346 - loss: 0.4643 - val_accuracy: 0.8005 - val_loss: 0.5931
# Epoch 53/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8327 - loss: 0.4736 - val_accuracy: 0.8069 - val_loss: 0.5637
# Epoch 54/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8331 - loss: 0.4703 - val_accuracy: 0.8126 - val_loss: 0.5662
# Epoch 55/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8321 - loss: 0.4733 - val_accuracy: 0.8134 - val_loss: 0.5492
# Epoch 56/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8373 - loss: 0.4589 - val_accuracy: 0.8143 - val_loss: 0.5450
# Epoch 57/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8397 - loss: 0.4557 - val_accuracy: 0.8165 - val_loss: 0.5534
# Epoch 58/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8393 - loss: 0.4494 - val_accuracy: 0.8202 - val_loss: 0.5347
# Epoch 59/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8428 - loss: 0.4380 - val_accuracy: 0.8188 - val_loss: 0.5466
# Epoch 60/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8459 - loss: 0.4324 - val_accuracy: 0.8113 - val_loss: 0.5564
# Epoch 61/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8437 - loss: 0.4367 - val_accuracy: 0.8164 - val_loss: 0.5519
# Epoch 62/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8428 - loss: 0.4377 - val_accuracy: 0.8146 - val_loss: 0.5513
# Epoch 63/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8462 - loss: 0.4284 - val_accuracy: 0.8182 - val_loss: 0.5460
# Epoch 64/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8497 - loss: 0.4193 - val_accuracy: 0.8154 - val_loss: 0.5523
# Epoch 65/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8480 - loss: 0.4256 - val_accuracy: 0.8219 - val_loss: 0.5513
# Epoch 66/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8460 - loss: 0.4288 - val_accuracy: 0.8182 - val_loss: 0.5537
# Epoch 67/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8538 - loss: 0.4053 - val_accuracy: 0.8190 - val_loss: 0.5666
# Epoch 68/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8518 - loss: 0.4155 - val_accuracy: 0.8208 - val_loss: 0.5399
# Epoch 69/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8533 - loss: 0.4093 - val_accuracy: 0.8169 - val_loss: 0.5402
# Epoch 70/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8508 - loss: 0.4088 - val_accuracy: 0.8135 - val_loss: 0.5618
# Epoch 71/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8557 - loss: 0.4068 - val_accuracy: 0.8191 - val_loss: 0.5445
# Epoch 72/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8571 - loss: 0.3965 - val_accuracy: 0.8144 - val_loss: 0.5739
# Epoch 73/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8521 - loss: 0.4080 - val_accuracy: 0.8144 - val_loss: 0.5716
# Epoch 74/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8598 - loss: 0.3898 - val_accuracy: 0.8228 - val_loss: 0.5427
# Epoch 75/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8615 - loss: 0.3858 - val_accuracy: 0.8200 - val_loss: 0.5435
# Epoch 76/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8587 - loss: 0.3963 - val_accuracy: 0.8197 - val_loss: 0.5384
# Epoch 77/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8627 - loss: 0.3763 - val_accuracy: 0.8171 - val_loss: 0.5688
# Epoch 78/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8626 - loss: 0.3825 - val_accuracy: 0.8213 - val_loss: 0.5549
# Epoch 79/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8635 - loss: 0.3766 - val_accuracy: 0.8187 - val_loss: 0.5503
# Epoch 80/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8654 - loss: 0.3741 - val_accuracy: 0.8225 - val_loss: 0.5439
# Epoch 81/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8660 - loss: 0.3734 - val_accuracy: 0.8232 - val_loss: 0.5462
# Epoch 82/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8672 - loss: 0.3708 - val_accuracy: 0.8234 - val_loss: 0.5538
# Epoch 83/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8693 - loss: 0.3729 - val_accuracy: 0.8254 - val_loss: 0.5505
# Epoch 84/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8679 - loss: 0.3777 - val_accuracy: 0.8244 - val_loss: 0.5480
# Epoch 85/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8715 - loss: 0.3624 - val_accuracy: 0.8234 - val_loss: 0.5500
# Epoch 86/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8703 - loss: 0.3634 - val_accuracy: 0.8230 - val_loss: 0.5460
# Epoch 87/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8728 - loss: 0.3635 - val_accuracy: 0.8253 - val_loss: 0.5558
# Epoch 88/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8702 - loss: 0.3603 - val_accuracy: 0.8248 - val_loss: 0.5476
# Epoch 89/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8738 - loss: 0.3492 - val_accuracy: 0.8237 - val_loss: 0.5511
# Epoch 90/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8754 - loss: 0.3499 - val_accuracy: 0.8278 - val_loss: 0.5407
# Epoch 91/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8760 - loss: 0.3437 - val_accuracy: 0.8201 - val_loss: 0.5659
# Epoch 92/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8737 - loss: 0.3524 - val_accuracy: 0.8268 - val_loss: 0.5450
# Epoch 93/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8747 - loss: 0.3530 - val_accuracy: 0.8269 - val_loss: 0.5458
# Epoch 94/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8753 - loss: 0.3444 - val_accuracy: 0.8279 - val_loss: 0.5392
# Epoch 95/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8774 - loss: 0.3467 - val_accuracy: 0.8268 - val_loss: 0.5292
# Epoch 96/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8806 - loss: 0.3382 - val_accuracy: 0.8284 - val_loss: 0.5462
# Epoch 97/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8795 - loss: 0.3310 - val_accuracy: 0.8270 - val_loss: 0.5319
# Epoch 98/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8802 - loss: 0.3292 - val_accuracy: 0.8262 - val_loss: 0.5445
# Epoch 99/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8828 - loss: 0.3278 - val_accuracy: 0.8276 - val_loss: 0.5503
# Epoch 100/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8771 - loss: 0.3368 - val_accuracy: 0.8263 - val_loss: 0.5547
# Epoch 101/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8813 - loss: 0.3324 - val_accuracy: 0.8193 - val_loss: 0.5768
# Epoch 102/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8777 - loss: 0.3319 - val_accuracy: 0.8281 - val_loss: 0.5533
# Epoch 103/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8807 - loss: 0.3336 - val_accuracy: 0.8282 - val_loss: 0.5518
# Epoch 104/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8841 - loss: 0.3235 - val_accuracy: 0.8287 - val_loss: 0.5459
# Epoch 105/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8864 - loss: 0.3190 - val_accuracy: 0.8249 - val_loss: 0.5528
# Epoch 106/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8842 - loss: 0.3171 - val_accuracy: 0.8249 - val_loss: 0.5655
# Epoch 107/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8848 - loss: 0.3222 - val_accuracy: 0.8229 - val_loss: 0.5812
# Epoch 108/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8812 - loss: 0.3317 - val_accuracy: 0.8273 - val_loss: 0.5429
# Epoch 109/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8849 - loss: 0.3164 - val_accuracy: 0.8272 - val_loss: 0.5530
# Epoch 110/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8900 - loss: 0.3080 - val_accuracy: 0.8242 - val_loss: 0.5563
# Epoch 111/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8833 - loss: 0.3237 - val_accuracy: 0.8282 - val_loss: 0.5564
# Epoch 112/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8849 - loss: 0.3200 - val_accuracy: 0.8274 - val_loss: 0.5509
# Epoch 113/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8858 - loss: 0.3167 - val_accuracy: 0.8295 - val_loss: 0.5451
# Epoch 114/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8918 - loss: 0.3073 - val_accuracy: 0.8252 - val_loss: 0.5627
# Epoch 115/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8863 - loss: 0.3136 - val_accuracy: 0.8287 - val_loss: 0.5484
# Epoch 116/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8909 - loss: 0.3126 - val_accuracy: 0.8292 - val_loss: 0.5477
# Epoch 117/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8880 - loss: 0.3100 - val_accuracy: 0.8298 - val_loss: 0.5504
# Epoch 118/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8920 - loss: 0.2970 - val_accuracy: 0.8300 - val_loss: 0.5610
# Epoch 119/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8903 - loss: 0.3039 - val_accuracy: 0.8287 - val_loss: 0.5553
# Epoch 120/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8872 - loss: 0.3153 - val_accuracy: 0.8255 - val_loss: 0.5705
# Epoch 121/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8931 - loss: 0.2963 - val_accuracy: 0.8286 - val_loss: 0.5709
# Epoch 122/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8886 - loss: 0.3001 - val_accuracy: 0.8312 - val_loss: 0.5503
# Epoch 123/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8955 - loss: 0.2968 - val_accuracy: 0.8314 - val_loss: 0.5420
# Epoch 124/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8933 - loss: 0.2931 - val_accuracy: 0.8263 - val_loss: 0.5642
# Epoch 125/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8942 - loss: 0.2919 - val_accuracy: 0.8328 - val_loss: 0.5457
# Epoch 126/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8968 - loss: 0.2906 - val_accuracy: 0.8284 - val_loss: 0.5733
# Epoch 127/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8928 - loss: 0.2936 - val_accuracy: 0.8336 - val_loss: 0.5456
# Epoch 128/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8957 - loss: 0.2870 - val_accuracy: 0.8335 - val_loss: 0.5448
# Epoch 129/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8954 - loss: 0.2864 - val_accuracy: 0.8346 - val_loss: 0.5611
# Epoch 130/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8938 - loss: 0.3009 - val_accuracy: 0.8320 - val_loss: 0.5617
# Epoch 131/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.8966 - loss: 0.2901 - val_accuracy: 0.8298 - val_loss: 0.5615
# Epoch 132/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8973 - loss: 0.2843 - val_accuracy: 0.8235 - val_loss: 0.5810
# Epoch 133/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8934 - loss: 0.2973 - val_accuracy: 0.8307 - val_loss: 0.5536
# Epoch 134/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8968 - loss: 0.2863 - val_accuracy: 0.8329 - val_loss: 0.5607
# Epoch 135/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8965 - loss: 0.2870 - val_accuracy: 0.8298 - val_loss: 0.5549
# Epoch 136/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8965 - loss: 0.2912 - val_accuracy: 0.8333 - val_loss: 0.5470
# Epoch 137/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8988 - loss: 0.2888 - val_accuracy: 0.8294 - val_loss: 0.5799
# Epoch 138/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8965 - loss: 0.2888 - val_accuracy: 0.8317 - val_loss: 0.5627
# Epoch 139/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8981 - loss: 0.2929 - val_accuracy: 0.8273 - val_loss: 0.5695
# Epoch 140/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9002 - loss: 0.2791 - val_accuracy: 0.8303 - val_loss: 0.5576
# Epoch 141/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9005 - loss: 0.2726 - val_accuracy: 0.8318 - val_loss: 0.5542
# Epoch 142/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8993 - loss: 0.2800 - val_accuracy: 0.8318 - val_loss: 0.5660
# Epoch 143/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8976 - loss: 0.2852 - val_accuracy: 0.8316 - val_loss: 0.5599
# Epoch 144/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8993 - loss: 0.2761 - val_accuracy: 0.8315 - val_loss: 0.5492
# Epoch 145/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9024 - loss: 0.2748 - val_accuracy: 0.8349 - val_loss: 0.5539
# Epoch 146/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8989 - loss: 0.2788 - val_accuracy: 0.8338 - val_loss: 0.5615
# Epoch 147/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9012 - loss: 0.2720 - val_accuracy: 0.8338 - val_loss: 0.5560
# Epoch 148/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9069 - loss: 0.2679 - val_accuracy: 0.8312 - val_loss: 0.5604
# Epoch 149/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8962 - loss: 0.2882 - val_accuracy: 0.8318 - val_loss: 0.5568
# Epoch 150/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9022 - loss: 0.2736 - val_accuracy: 0.8358 - val_loss: 0.5483
# Epoch 151/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9007 - loss: 0.2795 - val_accuracy: 0.8268 - val_loss: 0.5756
# Epoch 152/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9029 - loss: 0.2758 - val_accuracy: 0.8328 - val_loss: 0.5593
# Epoch 153/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9033 - loss: 0.2643 - val_accuracy: 0.8373 - val_loss: 0.5589
# Epoch 154/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9043 - loss: 0.2656 - val_accuracy: 0.8352 - val_loss: 0.5608
# Epoch 155/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8995 - loss: 0.2739 - val_accuracy: 0.8342 - val_loss: 0.5505
# Epoch 156/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9054 - loss: 0.2639 - val_accuracy: 0.8344 - val_loss: 0.5594
# Epoch 157/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9024 - loss: 0.2690 - val_accuracy: 0.8311 - val_loss: 0.5713
# Epoch 158/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9064 - loss: 0.2627 - val_accuracy: 0.8323 - val_loss: 0.5637
# Epoch 159/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9043 - loss: 0.2704 - val_accuracy: 0.8304 - val_loss: 0.5569
# Epoch 160/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9043 - loss: 0.2619 - val_accuracy: 0.8322 - val_loss: 0.5580
# Epoch 161/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9093 - loss: 0.2658 - val_accuracy: 0.8313 - val_loss: 0.5629
# Epoch 162/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9081 - loss: 0.2575 - val_accuracy: 0.8305 - val_loss: 0.5721
# Epoch 163/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9019 - loss: 0.2682 - val_accuracy: 0.8260 - val_loss: 0.5721
# Epoch 164/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9038 - loss: 0.2712 - val_accuracy: 0.8314 - val_loss: 0.5630
# Epoch 165/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9062 - loss: 0.2600 - val_accuracy: 0.8348 - val_loss: 0.5400
# Epoch 166/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9089 - loss: 0.2526 - val_accuracy: 0.8322 - val_loss: 0.5665
# Epoch 167/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9094 - loss: 0.2550 - val_accuracy: 0.8309 - val_loss: 0.5649
# Epoch 168/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9072 - loss: 0.2561 - val_accuracy: 0.8303 - val_loss: 0.5802
# Epoch 169/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9074 - loss: 0.2567 - val_accuracy: 0.8283 - val_loss: 0.5640
# Epoch 170/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9069 - loss: 0.2516 - val_accuracy: 0.8304 - val_loss: 0.5658
# Epoch 171/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9055 - loss: 0.2644 - val_accuracy: 0.8327 - val_loss: 0.5752
# Epoch 172/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9090 - loss: 0.2600 - val_accuracy: 0.8340 - val_loss: 0.5767
# Epoch 173/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9044 - loss: 0.2634 - val_accuracy: 0.8308 - val_loss: 0.5688
# Epoch 174/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9058 - loss: 0.2593 - val_accuracy: 0.8331 - val_loss: 0.5627
# Epoch 175/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9049 - loss: 0.2634 - val_accuracy: 0.8363 - val_loss: 0.5634
# Epoch 176/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9111 - loss: 0.2500 - val_accuracy: 0.8322 - val_loss: 0.5543
# Epoch 177/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9078 - loss: 0.2548 - val_accuracy: 0.8302 - val_loss: 0.5711
# Epoch 178/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9108 - loss: 0.2479 - val_accuracy: 0.8313 - val_loss: 0.5879
# Epoch 179/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9084 - loss: 0.2622 - val_accuracy: 0.8334 - val_loss: 0.5727
# Epoch 180/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9077 - loss: 0.2553 - val_accuracy: 0.8326 - val_loss: 0.5725
# Epoch 181/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9079 - loss: 0.2493 - val_accuracy: 0.8358 - val_loss: 0.5639
# Epoch 182/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9088 - loss: 0.2541 - val_accuracy: 0.8332 - val_loss: 0.5797
# Epoch 183/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9084 - loss: 0.2559 - val_accuracy: 0.8331 - val_loss: 0.5542
# Epoch 184/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9124 - loss: 0.2426 - val_accuracy: 0.8314 - val_loss: 0.5769
# Epoch 185/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9097 - loss: 0.2535 - val_accuracy: 0.8325 - val_loss: 0.5874
# Epoch 186/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9109 - loss: 0.2409 - val_accuracy: 0.8334 - val_loss: 0.5697
# Epoch 187/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9121 - loss: 0.2464 - val_accuracy: 0.8321 - val_loss: 0.5635
# Epoch 188/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9113 - loss: 0.2414 - val_accuracy: 0.8371 - val_loss: 0.5633
# Epoch 189/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9120 - loss: 0.2510 - val_accuracy: 0.8350 - val_loss: 0.5653
# Epoch 190/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9115 - loss: 0.2446 - val_accuracy: 0.8355 - val_loss: 0.5698
# Epoch 191/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9113 - loss: 0.2474 - val_accuracy: 0.8362 - val_loss: 0.5795
# Epoch 192/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9129 - loss: 0.2429 - val_accuracy: 0.8307 - val_loss: 0.5890
# Epoch 193/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9131 - loss: 0.2423 - val_accuracy: 0.8338 - val_loss: 0.5681
# Epoch 194/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9128 - loss: 0.2472 - val_accuracy: 0.8318 - val_loss: 0.5631
# Epoch 195/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9106 - loss: 0.2474 - val_accuracy: 0.8370 - val_loss: 0.5636
# Epoch 196/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9125 - loss: 0.2433 - val_accuracy: 0.8356 - val_loss: 0.5802
# Epoch 197/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9124 - loss: 0.2481 - val_accuracy: 0.8345 - val_loss: 0.5594
# Epoch 198/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9161 - loss: 0.2367 - val_accuracy: 0.8339 - val_loss: 0.5762
# Epoch 199/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9111 - loss: 0.2464 - val_accuracy: 0.8349 - val_loss: 0.5657
# Epoch 200/200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9150 - loss: 0.2379 - val_accuracy: 0.8370 - val_loss: 0.5774
# 313/313 - 1s - 3ms/step - accuracy: 0.8310 - loss: 0.6001
# 테스트 정확도: 0.8309999704360962
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 예측값 = [3 8 8 0 6 6 9 6 3 1 0 9 5 7 9 8 5 7 8 6 7 0 2 9 4]
# 실제값 = [3 8 8 0 6 6 1 6 3 1 0 9 5 7 9 8 5 7 8 6 7 0 4 9 5]
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 예측값 = [3 8 8 ... 5 1 7]
# 실제값 = [3 8 8 ... 5 1 7]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive
# %cd MyDrive
# %cd 인기초
# %ls
# Out:
# /content/drive
# /content/drive/MyDrive
# /content/drive/MyDrive/인기초
# flowers-dataset/
